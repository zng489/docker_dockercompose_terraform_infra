# %%
# !pip install hdfs
# Out:
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for hdfs: filename=hdfs-2.7.3-py3-none-any.whl size=34352 sha256=6575b0e67a1288000efa2f8df8fd2f8a6b5ab21febb491ebba8131a4c632d6d9
#   Stored in directory: c:\users\pc\appdata\local\pip\cache\wheels\68\dd\29\c1a590238f9ebbe4f7ee9b3583f5185d0b9577e23f05c990eb
# ...
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13775 sha256=7773b390e3a28a879058dfe150d793d82dae496fef7622da759a6de0d788a0f3
#   Stored in directory: c:\users\pc\appdata\local\pip\cache\wheels\56\ea\58\ead137b087d9e326852a851351d1debf4ada529b6ac0ec4e8c
# Successfully built hdfs docopt
# ...

# %%
from hdfs import InsecureClient

# Connect to HDFS
client = InsecureClient('http://localhost:9870', user='hadoop-namenode')

# List files in HDFS root directory
files = client.list('/')
print(files)
# Out:
# ---------------------------------------------------------------------------
# RemoteDisconnected                        Traceback (most recent call last)
# File c:\Users\PC\miniconda3\envs\nbconvert_3_8\lib\site-packages\urllib3\connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#
# ...
